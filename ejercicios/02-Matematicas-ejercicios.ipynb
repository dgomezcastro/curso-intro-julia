# %% [markdown]
# # 2. Matemáticas

# %% [markdown]
# 1. Resolver el modelo SIR
# $\dot S = -\beta S I, \qquad \dot I = \beta S I - \gamma I, \qquad \dot R = \gamma I$
# utilizando `DifferentialEquations.jl`

# %%
β = 0.5
γ = 1 / 3
S0 = 5.
I0 = 1.
R0 = 0.

# %%
# RESUELVA EL EJERCICIO AQUÏ

# %% [markdown]
# 2. Añadir incertidumbre al parámetro $\beta$ utilizando `Measurements.jl` y volver a ejecutar a resolver el modelo

# %%
using Measurements
β = 0.5 ± 0.1
# Out:
# 0.5 ± 0.1

# %%
# RESUELVA EL EJERCICIO AQUÏ

# %% [markdown]
# 3. Resolver SIR utilizando `ModelingToolkit.jl`

# %%
# RESUELVA EL EJERCICIO AQUÏ

# %% [markdown]
# 4. Adaptar el ejemplo de idenficación de parámetros [link](https://docs.sciml.ai/ModelingToolkit/stable/tutorials/dynamic_optimization/#Parameter-estimation) para generar datos sintéticos y aproximarlos usando el modelo del ejercicio 2

# %%
# RESUELVA EL EJERCICIO AQUÏ
